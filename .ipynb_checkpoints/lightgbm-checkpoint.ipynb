# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
import lightgbm as lgb

# %%
train_data=lgb.Dataset('train/train.csv')

# %%
params = {
    'num_leaves': 127,
    'objective': 'regression',
    'min_data_in_leaf': 100,
    'learning_rate': 0.015,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'metric': 'l2',
    'nthread': 32,
    'lambda_l1':0.10,
    'lambda_l2':0.10,
    'seed':1123,
    'header':True,
    'label':0
}

# %%
lgb_cb = lgb.cv(
    params,
    train_data,
    num_boost_round=10000,
    early_stopping_rounds=50,
    verbose_eval=50,    
)
# Out:
# /home/youchong/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:644: UserWarning: label keyword has been found in `params` and will be ignored. Please use label argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# /home/youchong/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# [50]	cv_agg's l2: 4.03256 + 1.11507
# [100]	cv_agg's l2: 3.69836 + 1.03841
# [150]	cv_agg's l2: 3.51306 + 0.979809
# [200]	cv_agg's l2: 3.39547 + 0.940566
# [250]	cv_agg's l2: 3.30716 + 0.903774
# [300]	cv_agg's l2: 3.24006 + 0.87337
# [350]	cv_agg's l2: 3.18936 + 0.850402
# [400]	cv_agg's l2: 3.1514 + 0.834578
# [450]	cv_agg's l2: 3.12001 + 0.820348
# [500]	cv_agg's l2: 3.0952 + 0.811641
# [550]	cv_agg's l2: 3.0763 + 0.802665
# [600]	cv_agg's l2: 3.06034 + 0.794587
# [650]	cv_agg's l2: 3.04661 + 0.786678
# [700]	cv_agg's l2: 3.03395 + 0.781297
# [750]	cv_agg's l2: 3.02353 + 0.775839
# [800]	cv_agg's l2: 3.01376 + 0.770007
# [850]	cv_agg's l2: 3.00409 + 0.762937
# [900]	cv_agg's l2: 2.99614 + 0.757055
# [950]	cv_agg's l2: 2.98882 + 0.752988
# [1000]	cv_agg's l2: 2.98246 + 0.748301
# [1050]	cv_agg's l2: 2.97517 + 0.742293
# [1100]	cv_agg's l2: 2.96793 + 0.736328
# [1150]	cv_agg's l2: 2.9624 + 0.732803
# [1200]	cv_agg's l2: 2.95598 + 0.726755
# [1250]	cv_agg's l2: 2.95035 + 0.721473
# [1300]	cv_agg's l2: 2.94534 + 0.717779
# [1350]	cv_agg's l2: 2.94056 + 0.713975
# [1400]	cv_agg's l2: 2.93625 + 0.710684
# [1450]	cv_agg's l2: 2.9328 + 0.70908
# [1500]	cv_agg's l2: 2.92873 + 0.706101
# [1550]	cv_agg's l2: 2.92563 + 0.703837
# [1600]	cv_agg's l2: 2.92203 + 0.700077
# [1650]	cv_agg's l2: 2.9187 + 0.696927
# [1700]	cv_agg's l2: 2.91571 + 0.694014
# [1750]	cv_agg's l2: 2.91288 + 0.691732
# [1800]	cv_agg's l2: 2.91051 + 0.689499
# [1850]	cv_agg's l2: 2.90729 + 0.685405
# [1900]	cv_agg's l2: 2.90439 + 0.681802
# [1950]	cv_agg's l2: 2.90206 + 0.67887
# [2000]	cv_agg's l2: 2.9002 + 0.676794
# [2050]	cv_agg's l2: 2.89891 + 0.675457
# [2100]	cv_agg's l2: 2.89622 + 0.672321
# [2150]	cv_agg's l2: 2.89383 + 0.669994
# [2200]	cv_agg's l2: 2.89183 + 0.667419
# [2250]	cv_agg's l2: 2.88981 + 0.664844
# [2300]	cv_agg's l2: 2.88868 + 0.663754
# [2350]	cv_agg's l2: 2.88725 + 0.661547
# [2400]	cv_agg's l2: 2.88598 + 0.659724
# [2450]	cv_agg's l2: 2.88446 + 0.657435
# [2500]	cv_agg's l2: 2.88313 + 0.655319
# [2550]	cv_agg's l2: 2.882 + 0.654419
# [2600]	cv_agg's l2: 2.88038 + 0.652528
# [2650]	cv_agg's l2: 2.87884 + 0.650695
# [2700]	cv_agg's l2: 2.87772 + 0.64916
# [2750]	cv_agg's l2: 2.8762 + 0.64768
# [2800]	cv_agg's l2: 2.87587 + 0.64689
# [2850]	cv_agg's l2: 2.87491 + 0.646079
# [2900]	cv_agg's l2: 2.87356 + 0.644236
# [2950]	cv_agg's l2: 2.87262 + 0.643171
# [3000]	cv_agg's l2: 2.87063 + 0.640655
# [3050]	cv_agg's l2: 2.87 + 0.639564
# [3100]	cv_agg's l2: 2.86948 + 0.637908
# [3150]	cv_agg's l2: 2.86815 + 0.635873
# [3200]	cv_agg's l2: 2.86722 + 0.634662
# [3250]	cv_agg's l2: 2.86643 + 0.63324
# [3300]	cv_agg's l2: 2.86523 + 0.631337
# [3350]	cv_agg's l2: 2.86424 + 0.629867
# [3400]	cv_agg's l2: 2.86313 + 0.628189
# [3450]	cv_agg's l2: 2.8621 + 0.626742
# [3500]	cv_agg's l2: 2.86156 + 0.625759
# [3550]	cv_agg's l2: 2.86098 + 0.624209
# [3600]	cv_agg's l2: 2.86007 + 0.622653
# [3650]	cv_agg's l2: 2.85939 + 0.621173
# [3700]	cv_agg's l2: 2.8586 + 0.620253
# [3750]	cv_agg's l2: 2.85769 + 0.618495
# [3800]	cv_agg's l2: 2.85683 + 0.617162
# [3850]	cv_agg's l2: 2.8567 + 0.616584
# [3900]	cv_agg's l2: 2.85611 + 0.616
# [3950]	cv_agg's l2: 2.85507 + 0.613352
# [4000]	cv_agg's l2: 2.85469 + 0.61202
# [4050]	cv_agg's l2: 2.85434 + 0.610515
# [4100]	cv_agg's l2: 2.85378 + 0.609709
# [4150]	cv_agg's l2: 2.8537 + 0.608991
# [4200]	cv_agg's l2: 2.853 + 0.606942
# [4250]	cv_agg's l2: 2.85259 + 0.606189
# [4300]	cv_agg's l2: 2.85236 + 0.605276
# [4350]	cv_agg's l2: 2.85182 + 0.604553
# [4400]	cv_agg's l2: 2.85174 + 0.604292
# [4450]	cv_agg's l2: 2.85125 + 0.603142

# %%
nround = lgb_cb['l2-mean'].index(np.min(lgb_cb['l2-mean']))

# %%
nround
# Out:
# 4436

# %%
bst=lgb.train(
    params,
    train_data,
    num_boost_round=nround,
    verbose_eval=50
)

# %%
test_data=pd.read_csv('train/test.csv')

# %%
test_data.head()
# Out:
#    test_id  create_hour  text  code  temperature  feels_like  pressure  \
# 0        0           21   1.0   4.0         29.0        29.0    1003.0
# 1        1           21   1.0   4.0         29.0        29.0    1003.0
# 2        2           21   1.0   4.0         29.0        29.0    1003.0
# 3        3           17   1.0   4.0         31.0        31.0    1001.0
# 4        4           17   1.0   4.0         31.0        31.0    1001.0
#
#    humidity  visibility  wind_direction   ...     petrol_station_y  \
# 0      70.0        10.0             4.0   ...                  2.0
# 1      70.0        10.0             4.0   ...                  2.0
# 2      70.0        10.0             4.0   ...                  2.0
# 3      64.0        13.4             4.0   ...                  2.0
# 4      64.0        13.4             4.0   ...                  2.0
#
#    supermarket_y  uptown_y  subway_station_y  bus_station_y  coffee_House_y  \
# 0           79.0     266.0               7.0           36.0            95.0
# 1           61.0     152.0               4.0           34.0           115.0
# 2           47.0     244.0               6.0           35.0           157.0
# 3           61.0     152.0               4.0           34.0           115.0
# 4           40.0     324.0               7.0           55.0            42.0
#
#    restaurant_y  atm_y  office_building_y  hotel_y
# 0         898.0  113.0              133.0    151.0
# 1         900.0  114.0              167.0    117.0
# 2         898.0  107.0              177.0    186.0
# 3         900.0  114.0              167.0    117.0
# 4         693.0  164.0              174.0    132.0
#
# [5 rows x 34 columns]

# %%
test_id=test_data['test_id']
test_data.drop(['test_id'],axis=1,inplace=True)

# %%
test_data.head()
# Out:
#    create_hour  text  code  temperature  feels_like  pressure  humidity  \
# 0           21   1.0   4.0         29.0        29.0    1003.0      70.0
# 1           21   1.0   4.0         29.0        29.0    1003.0      70.0
# 2           21   1.0   4.0         29.0        29.0    1003.0      70.0
# 3           17   1.0   4.0         31.0        31.0    1001.0      64.0
# 4           17   1.0   4.0         31.0        31.0    1001.0      64.0
#
#    visibility  wind_direction  wind_direction_degree   ...     \
# 0        10.0             4.0                  129.0   ...
# 1        10.0             4.0                  129.0   ...
# 2        10.0             4.0                  129.0   ...
# 3        13.4             4.0                  124.0   ...
# 4        13.4             4.0                  124.0   ...
#
#    petrol_station_y  supermarket_y  uptown_y  subway_station_y  bus_station_y  \
# 0               2.0           79.0     266.0               7.0           36.0
# 1               2.0           61.0     152.0               4.0           34.0
# 2               2.0           47.0     244.0               6.0           35.0
# 3               2.0           61.0     152.0               4.0           34.0
# 4               2.0           40.0     324.0               7.0           55.0
#
#    coffee_House_y  restaurant_y  atm_y  office_building_y  hotel_y
# 0            95.0         898.0  113.0              133.0    151.0
# 1           115.0         900.0  114.0              167.0    117.0
# 2           157.0         898.0  107.0              177.0    186.0
# 3           115.0         900.0  114.0              167.0    117.0
# 4            42.0         693.0  164.0              174.0    132.0
#
# [5 rows x 33 columns]

# %%
ypred = bst.predict(test_data)

# %%
ypred
# Out:
# array([ 18.34927644,  10.84051368,   8.17009857, ...,   1.33679928,
#          1.46260104,   1.16174553])

# %%
submission = pd.DataFrame({
        "test_id": test_id,
    })

# %%
submission['count']=ypred

# %%
submission.head()
# Out:
#    test_id      count
# 0        0  18.349276
# 1        1  10.840514
# 2        2   8.170099
# 3        3   9.257586
# 4        4   8.130158

# %%
submission.to_csv('data/submission/sub_1.csv',index=False)
