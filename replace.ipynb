# %%
import pandas as pd
import numpy as np
import random as rnd

# %%
train=pd.read_csv('train/train_1.csv')
test=pd.read_csv('train/test_1.csv')
poi=pd.read_csv('data/pio_treated.csv')

# %%
train.head()
# Out:
#    count                      start_geo_id                        end_geo_id  \
# 0      1  0175b8486a67a505f0dc183f6df7f750  e8075aa7f0fc96871cc204bea0696b43
# 1      1  02fa9f7cd1d2c5dfdb32ed9c2aec23d9  bae435e54e698139d5dfda788f91f32e
# 2      1  02fa9f7cd1d2c5dfdb32ed9c2aec23d9  f5dc996f6aa097f7a84a9bcfe58ed55c
# 3      1  0a64b01e91cf367a9b016d4f6d42290f  0613fd690240317177a03a0b26ca8591
# 4      1  0a64b01e91cf367a9b016d4f6d42290f  0a64b01e91cf367a9b016d4f6d42290f
#
#    year  month  day  create_hour  hour  text  code   ...     petrol_station_y  \
# 0  2017      7    1            0     0     2     1   ...                  1.0
# 1  2017      7    1            0     0     2     1   ...                  0.0
# 2  2017      7    1            0     0     2     1   ...                  2.0
# 3  2017      7    1            0     0     2     1   ...                  4.0
# 4  2017      7    1            0     0     2     1   ...                  4.0
#
# ...

# %%
test.head()
# Out:
#    test_id                      start_geo_id  \
# 0        0  3d99665144344fc090b5b7450ffe72f5
# 1        1  71adb79e626fb1b09726781fe0c4a7a0
# 2        2  e8e8612bf79d1c6fb1d74e42d039e912
# 3        3  27d75f17e61587172fe7a6827bbaa198
# 4        4  fc285cf482f1014cd81d5ba233ac9569
#
#                          end_geo_id  year  month  day  create_hour  hour  \
# 0  3fcb2fe11c0c68c5f7a8d19a04689e1b  2017      8    1           23    23
# 1  71adb79e626fb1b09726781fe0c4a7a0  2017      8    1           15    15
# 2  aa0885cb765d5748a3bc5387a1f18b24  2017      8    1           21    21
# 3  f5dc996f6aa097f7a84a9bcfe58ed55c  2017      8    1           23    23
# 4  6d7827e8dcfa09497954a31e6f7e6ee6  2017      8    1           11    11
#
#    text  code   ...     petrol_station_y  supermarket_y  uptown_y  \
# 0     1     4   ...                  2.0           41.0     205.0
# 1     1     4   ...                  3.0           31.0     170.0
# ...

# %%
geo_id=pd.concat([train['start_geo_id'],train['end_geo_id'],test['start_geo_id'],test['end_geo_id']])

# %%
geo_id=geo_id.unique().tolist()

# %%
relist=[]
for i in range(len(geo_id)):
    relist.append(i+1000)

# %%
test.replace(geo_id,relist,inplace=True)

# %%
train.replace(geo_id,relist,inplace=True)

# %%
test.head()
# Out:
#    test_id  start_geo_id  end_geo_id  year  month  day  create_hour  hour  \
# 0        0          1022        1023  2017      8    1           23    23
# 1        1          1037        1037  2017      8    1           15    15
# 2        2          1080        1062  2017      8    1           21    21
# 3        3          1015        1085  2017      8    1           23    23
# 4        4          1091        1033  2017      8    1           11    11
#
#    text  code   ...     petrol_station_y  supermarket_y  uptown_y  \
# 0     1     4   ...                  2.0           41.0     205.0
# 1     1     4   ...                  3.0           31.0     170.0
# 2     1     4   ...                  3.0           32.0     271.0
# 3     1     4   ...                  2.0           62.0     180.0
# 4     6     9   ...                  1.0            7.0      23.0
#
#    subway_station_y  bus_station_y  coffee_House_y  restaurant_y  atm_y  \
# ...

# %%
train.head()
# Out:
#    count  start_geo_id  end_geo_id  year  month  day  create_hour  hour  text  \
# 0      1          1000        1136  2017      7    1            0     0     2
# 1      1          1001        1215  2017      7    1            0     0     2
# 2      1          1001        1085  2017      7    1            0     0     2
# 3      1          1002        1129  2017      7    1            0     0     2
# 4      1          1002        1002  2017      7    1            0     0     2
#
#    code   ...     petrol_station_y  supermarket_y  uptown_y  subway_station_y  \
# 0     1   ...                  1.0           38.0      51.0               4.0
# 1     1   ...                  0.0           18.0      30.0               1.0
# 2     1   ...                  2.0           62.0     180.0               3.0
# 3     1   ...                  4.0           32.0      50.0               3.0
# 4     1   ...                  4.0           61.0     233.0               6.0
#
# ...

# %%
test.columns
# Out:
# Index(['test_id', 'start_geo_id', 'end_geo_id', 'year', 'month', 'day',
#        'create_hour', 'hour', 'text', 'code', 'temperature', 'feels_like',
#        'pressure', 'humidity', 'visibility', 'wind_direction',
#        'wind_direction_degree', 'wind_speed', 'wind_scale', 'petrol_station_x',
#        'supermarket_x', 'uptown_x', 'subway_station_x', 'bus_station_x',
#        'coffee_House_x', 'restaurant_x', 'atm_x', 'office_building_x',
#        'hotel_x', 'petrol_station_y', 'supermarket_y', 'uptown_y',
#        'subway_station_y', 'bus_station_y', 'coffee_House_y', 'restaurant_y',
#        'atm_y', 'office_building_y', 'hotel_y'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['count', 'start_geo_id', 'end_geo_id', 'year', 'month', 'day',
#        'create_hour', 'hour', 'text', 'code', 'temperature', 'feels_like',
#        'pressure', 'humidity', 'visibility', 'wind_direction',
#        'wind_direction_degree', 'wind_speed', 'wind_scale', 'petrol_station_x',
#        'supermarket_x', 'uptown_x', 'subway_station_x', 'bus_station_x',
#        'coffee_House_x', 'restaurant_x', 'atm_x', 'office_building_x',
#        'hotel_x', 'petrol_station_y', 'supermarket_y', 'uptown_y',
#        'subway_station_y', 'bus_station_y', 'coffee_House_y', 'restaurant_y',
#        'atm_y', 'office_building_y', 'hotel_y'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
train[train.isnull().values==True]
# Out:
#         count  start_geo_id  end_geo_id  year  month  day  create_hour  hour  \
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 502499      1          1345        2251  2017      8    1            8     8
# 504675      1          1086        2252  2017      8    1           12    12
# ...

# %%
test[test.isnull().values==True]
# Out:
#       test_id  start_geo_id  end_geo_id  year  month  day  create_hour  hour  \
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 131       131          2282        1057  2017      8    1           23    23
# 263       263          1887        2284  2017      8    1            9     9
# ...

# %%
train.to_csv('train/train_2.csv',index=False)

# %%
test.to_csv('train/test_2.csv',index=False)
