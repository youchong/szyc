# %%
import pandas as pd
import numpy as np
import random as rnd

# %%
poi=pd.read_csv('data/poi.csv',encoding='GBK')

# %%
poi.head()
# Out:
#    829fd9e04ed5f0e2148096737edb8a73  加油站  0  超市  0.1  住宅区    1  地铁站  0.2  公交站  \
# 0  3d99665144344fc090b5b7450ffe72f5  加油站  4  超市   43  住宅区  151  地铁站    4  公交站
# 1  f524dc6b89fcb9e4a9688c0cb7b2bdb7  加油站  0  超市    0  住宅区    0  地铁站    0  公交站
# 2  0613fd690240317177a03a0b26ca8591  加油站  4  超市   32  住宅区   50  地铁站    3  公交站
# 3  687ea595a01fdc18ad438f0d0a325102  加油站  0  超市    3  住宅区    1  地铁站    0  公交站
# 4  3bee6a7b93130a1359165736c6ea0850  加油站  0  超市    0  住宅区    0  地铁站    0  公交站
#
#   ...  咖啡厅 0.3  中餐厅  0.4  ATM 0.5  写字楼 0.6  酒店 0.7
# 0 ...  咖啡厅  22  中餐厅  597  ATM  59  写字楼  47  酒店  45
# 1 ...  咖啡厅   0  中餐厅    0  ATM   0  写字楼   0  酒店   0
# 2 ...  咖啡厅   6  中餐厅  509  ATM  20  写字楼   9  酒店  27
# 3 ...  咖啡厅   0  中餐厅    6  ATM   0  写字楼   0  酒店   1
# 4 ...  咖啡厅   0  中餐厅    0  ATM   0  写字楼   0  酒店   0
#
# [5 rows x 21 columns]

# %%
poi.columns.values
# Out:
# array(['829fd9e04ed5f0e2148096737edb8a73', '加油站', '0', '超市', '0.1', '住宅区',
#        '1', '地铁站', '0.2', '公交站', '2', '咖啡厅', '0.3', '中餐厅', '0.4', 'ATM',
#        '0.5', '写字楼', '0.6', '酒店', '0.7'], dtype=object)

# %%
weather=pd.read_csv('data/weather.csv')

# %%
weather.head()
# Out:
#             date text  code  temperature  feels_like  pressure  humidity  \
# 0  2017-7-1 0:30    晴     1           29        28.0       998        62
# 1  2017-7-1 1:00    晴     1           28        28.0       998        63
# 2  2017-7-1 1:30    晴     1           28        28.0       998        65
# 3  2017-7-1 2:00    晴     1           28        27.0       998        66
# 4  2017-7-1 2:30    晴     1           28        27.0       998        67
#
#    visibility wind_direction  wind_direction_degree  wind_speed  wind_scale
# 0         9.3              南                    200        9.00           2
# 1         7.7             西南                    233        7.92           2
# 2         7.7              南                    197        7.20           2
# 3         7.7             西南                    233        9.00           2
# 4         6.6              南                    180        7.20           2

# %%
weather.columns.values
# Out:
# array(['date', 'text', 'code', 'temperature', 'feels_like', 'pressure',
#        'humidity', 'visibility', 'wind_direction', 'wind_direction_degree',
#        'wind_speed', 'wind_scale'], dtype=object)
